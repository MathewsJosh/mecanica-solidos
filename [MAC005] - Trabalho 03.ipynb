# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewsJosh/mecanica-solidos/blob/main/%5BMAC005%5D%20-%20Trabalho%2003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Condições Gerais
#
# Esta avaliação tem como objetivo avaliar os conhecimentos adquiridos durante a disciplina de Mecânica dos Sólidos.
#
# Essa forma de avaliação tem por objetivo promover a discussão dos exercícios entre os membros do grupo (e eventualmente entre grupos) e ampliar a diversidade de exercícios a serem realizados.
#
# ---
#
# As condicões abaixo devem ser observadas:
#
# 1. Serão formadas equipes e cada uma delas com no mínimo 3 e no máximo 4 integrantes.
#
# 2. A avaliação será realizada por meio da entrega de uma cópia deste notebook com as soluções desenvolvidas até a data estipulada de entrega.
#
#
# 3. Da entrega da avaliação.
#   * Os documentos necessários para a entrega do trabalho são os códigos  desenvolvidos pela equipe.
#   * A equipe deve usar este modelo de notebook para desenvolver os códigos.
#   * Os códigos podem ser desenvolvidos combinado a linguagem LaTeX e computação simbólica via python quando necessário.
#
# 4. Da distribuição das questões.
#   * Serão atribuídas as mesmas questões referentes ao capítulo 3 do
#   livro texto (consultar as questões no [material anexo](https://drive.google.com/file/d/1nXONMdZTqkt5Y0MLjKNYsnoE4jeltdY-/view?usp=sharing).
#   * A pontuacão referente a cada questão será igualitária e o valor total da avaliação será 100 pontos.
#
# 5. As equipes devem ser formadas até às **18 horas o dia 22/02/2022** por meio do preenchimento da planilha [[MAC005] Formação das Equipes](https://docs.google.com/spreadsheets/d/1j59WVAl1cMzXgupwG86WFNGAQhbtVtc0b5aIQSbqGQE/edit#gid=986079240).
#   * Cada equipe será indentificada por uma letra em ordem alfabética seguida do número 3 (A3, B3, C3, e assim por diante). O arquivo está aberto para edição e pode ser alterado pelos alunos até a data estipulada.
#   * A equipe deve indicar no arquivo um responsável pela entrega do projeto.
#   * Somente o responsável pela entrega deve fazer o upload do arquivo na plataforma.
#
# 6. Equipes formadas após a data estabelecida para a formação das equipes terão a nota da avaliação multiplicada por um coeficiente de **0.80**.
#
# 7. A entrega dos projetos deve ocorrer até às **23:59 do dia 25/02/2021** na plataforma da disciplina pelo responsável pela entrega.
#   * Caso a entrega seja feita por outro integrante diferente daquele indicado pela pela equipe a avaliação será desconsiderada e não será corrigida até que a a condição de entrega seja satisfeita.
#
# 8. Quaisquer dúvidas ou esclarecimentos devem ser encaminhadas pela sala de aula virtual.

# %% [markdown]
# # Exercícios a serem resolvidos

# %% [markdown]
# ### 4.31

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# É dado pelo enunciado que a força de corpo é $B = -ge_3$, ou seja, $B = (0,0,-g)$. Sabemos também que a equação de equilíbrio dada pelo princípio do momento linear é $\frac{∂T_{ij}}{∂x_j} + ρB_i = 0$. Substituindo tais dados na equação de equilíbrio, temos que:
# <br><br>
# * $\frac{∂T_{11}}{∂x_1} + \frac{∂T_{12}}{∂x_2} + \frac{∂T_{13}}{∂x_3} + ρB_1 = 0 → 0 + 0 + 0 + ρ*0 = 0 → 0 = 0$
# <br><br><br>
# * $\frac{∂T_{21}}{∂x_1} + \frac{∂T_{22}}{∂x_2} + \frac{∂T_{23}}{∂x_3} + ρB_2 = 0 → 0 + 0 + 0 + ρ*0 = 0 → 0 = 0$
# <br><br><br>
# * $\frac{∂T_{31}}{∂x_1} + \frac{∂T_{32}}{∂x_2} + \frac{∂T_{33}}{∂x_3} + ρB_3 = 0 → 0 + (-α) + (α\frac{∂T_{33}}{∂x_3}) + ρ*(-g) = 0 → $ <br><br> $
#   α(-1 + \frac{∂T_{33}}{∂x_3}) - ρg = 0
#   → (-1 + \frac{∂T_{33}}{∂x_3}) = \frac{ρg}{α} → $ <br><br> $
#   \frac{∂T_{33}}{∂x_3} = \frac{ρg}{α} + 1
#   → \int \frac{∂T_{33}}{∂x_3}dx_3 = \int (\frac{ρg}{α} + 1)dx_3 → $ <br><br> $
#   T_{33} = (\frac{ρg}{α} + 1)x_3 + c$ , onde $ c = f(x_1, x_2) $

# %% [markdown]
# ## 4.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Alternativa a)
# Para mostrar que o plano com tensão na direção e3 é o unico plano no qual o vetor de tensão é zero, podemos fazer:
#
# $[t] = \begin{bmatrix} 1 & 0 & 0\\ 0 & -1 & 0\\ 0 & 0 & 0 \end{bmatrix} \begin{bmatrix} n_1\\ n_2\\ n_3\end{bmatrix} = \begin{bmatrix} n_1\\ -n_2\\ 0\end{bmatrix}$
#
# O que implica em:
#
# $t = n_1e_1 - n_2e_2$
#
# Considerando t=0:
#
# $t=0 → n_1 = 0, n_2 = 0$
#
# Por fim, temos que $t=e_3$.

# %% [markdown]
# Alternativa b)
# Encontraremos três planos nos quais não há uma ação de stress normal.
#
# $T_n = n*t = n_1^2 - n_2^2$
#
# Dessa forma, podemos considerar que um plano $n_1^2 - n_2^2=0$, não tem um stress normal.
#
# Consequentemente também podemos encontrar os planos:
# $n=\frac{(e_1+e_2)}{\sqrt{2}}$,
# $n=\frac{(e_1-e_2)}{\sqrt{2}}$,
# $n=e_3$

# %% [markdown]
# ## 4.10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A) A partir dos dados presentes no enunciado e da seção 4 do livro-texto que aborda o tensor tensão e as suas componentes, podemos partir para algumas definições relacionadas com a superfície lateral:
#
# $n_1 = \frac{x_2e_2 + x_3e_3}{2}$
#
# Para a face extrema, temos:
#
# $n_2 = -e_1$
#
# E para a outra face extrema da estrutura:
#
# $n_3 = e_1$
#
# Com isso, usando o tensor T do enunciado, podemos fazer:
#
# i) $ t_{e1} = \frac{1}{2}*[T]*[0,x_2,x_3] =  \frac{1}{2} * \begin{bmatrix} 0 & -αx_3 & α
# x_2 \\ -αx_3 & 0 & 0 \\ αx_2 & 0 & 0 \end{bmatrix} *  \begin{bmatrix} 0 \\ x_2 \\ x_3 \end{bmatrix} = \begin{bmatrix} 0 \\ 0 \\ 0 \end{bmatrix}$
#
# ii) $ t_{e2} = -Te_1 = -(-αx_3e_2 + αx_2e_3) = αx_3e_2 - αx_2e_3$
#
# iii) $t_{e3} = Te_1 = (-αx_3e_2 + αx_2e_3) = -αx_3e_2 + αx_2e_3$
#
# Dessa forma, temos as componentes do tensor tensão nas superfícies definidas.
#
# B) Primeiro, vamos encontrar a força resultante total na face extrema em que $x_1 = 𝓵$.
# De acordo com a resposta da letra A, temos que $t_{e3} = -αx_3e_2 + αx_2e_3$. Com isso, podemos montar a integral:
#
# $∫(-αx_3e_2 + αx_2e_3)dA = -αe_2 ∫ x_3dA + αe_3 ∫ x_2 dA = 0$
#
# Observando que os eixos acima são eixos de simetria, podemos considerar que o resultado da integração será zero. Para esse tipo de caso, podemos pensar no exemplo em que haverá a mesma quantidade de produtos $x_1x_2dA$ do que produtos $− x_1x_2dA$ em toda a área e a integral é zero.

# %% [markdown]
# ## 4.11

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A)
# Precisamos mostrar que o vetor de tensão em qualquer ponto $(x_1, x_2, x_3)$ da superfície lateral é zero. Para isso, sabendo que a superfície lateral da barra elíptica é definida por $x_{2}^2 + 2x_{3}^2 = 1$, podemos considerar que o vetor unitário normal dessa superfície é dado por:
#
# $n_1 = \frac{x_2e_2 + 2x_3e_3}{\sqrt{x_{2}^2 + 4x_{3}^2}}$
#
# A partir da seção 4 do livro-texto que aborda o tensor tensão e as suas componentes, podemos fazer a seguinte operação:
#
# Sendo $y = \sqrt{x_{2}^2 + 4x_{3}^2}$
#
# $ t = [T]*[n_1] = \begin{bmatrix} 0 & -2x_3 & x_2 \\ -2x_3 & 0 & 0 \\ x_2 & 0 & 0 \end{bmatrix} \begin{bmatrix} 0 \\ x_2 \\ 2x_3 \end{bmatrix} *y =  \begin{bmatrix} 0 \\ 0 \\ 0 \end{bmatrix}$
#
# Ao fazer essa multiplicação, confirmamos que o vetor será nulo para qualquer posição na lateral da superfície.
#
# B)
# Para encontrar a força resultante do vetor de tensão na extremidade esquerda da face $x_1$, podemos calcular a seguinte integral:
#
# Sendo $x_1  = 0, n = -e_1$ e o vetor de tensão como $2x_3e_2 - x_2e_3$.
#
# Assim,
#
# $∫(2x_3e_2 - x_2e_3)dA = 2e_2 ∫x_3dA - e_3 ∫ x_2dA = 0$.
#
# Da mesma forma como foi visto na resposta da questão 4.10, temos um caso em que os eixos são eixos de simetria, o que resulta em uma integral igual a 0. Para pensar nessa questão, podemos usar o exemplo em que haverá a mesma quantidade de produtos $x_1x_2dA$ do que produtos $− x_1x_2dA$ em toda a área de uma integral.
#
# Para calcular o momento resultante, fazemos outra integração:
#
# $∫(x_2e_2 - x_3e_3)(2x_3e_2 - x_2e_3)dA$
#
# Que nos dá:
#
# $-∫e_1(x_2^2+2x_3^2)dA = -e_1∫x_2^2dA + ∫2x_3^2dA$
#
# Usando os dados do enunciado, temos o resultado:
#
# $-e_1(\frac{Π}{4\sqrt{2}}+\frac{2Π}{8\sqrt{2}}) = -e_1(\frac{Π}{4\sqrt{2}}+\frac{Π}{4\sqrt{2}}) = -e_1\frac{2Π}{4\sqrt{2}} = -e_1\frac{Π}{2\sqrt{2}}$.

# %% [markdown]
# ## 4.13

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (a) Ao redor de cada ponto existem 8 planos octaédricos, que formam, juntamente, um octaedro. Como formam ângulos iguais com cada plano ($e_1, e_2, e_3$), possuem cossenos diretores que valem $|1/\sqrt{3}|$. <br><br>
# (b) Sendo o tensor na origem dado por:<br><br>
#
#  $δ_{ij} = \begin{bmatrix}
# δ_1 & 0 & 0 \\
# 0 & δ_2 & 0 \\
# 0 & 0 & δ_3
# \end{bmatrix}$
# <br><br>
# Sabendo-se também que a normal para um plano octaédrico é:<br><br>
# $\frac{e_1 +-e_2 +- e_3}{\sqrt{3}}$
# <br><br>
# Sendo assim, o  estresse normal pode ser dado como:<br><br>
# $T_n = nTn = \frac{1}{3}\begin{bmatrix} 1 & -1 & 1\end{bmatrix}\begin{bmatrix}
# δ_1 & 0 & 0 \\
# 0 & δ_2 & 0 \\
# 0 & 0 & δ_3
# \end{bmatrix}
# \begin{bmatrix}
# 1  \\
# +-1  \\
# +-1
# \end{bmatrix}\\
# T_n = \frac{1}{3}(δ_1 + δ_2 + δ_3)$
# <br><br>
# (c) A tensão cisalhante num plano octaédrico pode ser calculada da seguinte forma:
# <br><br>
# $T_s^2 = |t_n^2|- T^2_n = \frac{1}{3}(\delta_1^2 + \delta_2^2 + \delta_3^2) -\frac{1}{9}(\delta_1^2 + \delta_2^2 + \delta_3^2 + 2\delta_1\delta_2 + 2\delta_2\delta_3 + 2\delta_1\delta_3)\\
# T_s^2 = \frac{2}{9}(\delta_1^2 + \delta_2^2 + \delta_3^2-\delta_1\delta_2 + -\delta_2\delta_3 -\delta_1\delta_3) \\
# T_s^2 = \frac{1}{9}((\delta_1 - \delta_2)^2 + (\delta_2 - \delta_3)^2 + (\delta_3 - \delta_1)^2)
# $<br><br>
# Como dito no enunciado, a equação anterior pode ser reescrita como:
# <br><br>
# $T_s = \frac{1}{3}((\delta_1 - \delta_2)^2 + (\delta_2 - \delta_3)^2 + (\delta_3 - \delta_1)^2)^{1/2}\\
# T_s =  \frac{1}{3}[(T_1 - T_2)^2 + (T_2 - T_3)^2 + (T_3 - T_1)^2]^{1/2}$

# %% [markdown]
# ## 4.24

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Podemos encontrar as principais tensões de $T_{11}$ e $T_{33}$ a partir das equações características de T. Dadas abaixo: \\
# $I_1 = T_{11}+ T_{22} + T_{33}$ \\
# $I_2 = \begin{bmatrix} T_{11} & T_{12}\\ T_{21} & T_{22} \end{bmatrix}\begin{bmatrix} T_{11} & T_{13}\\ T_{31} & T_{33} \end{bmatrix}\begin{bmatrix} T_{22} & T_{23}\\ T_{32} & T_{33} \end{bmatrix}$ \\
# $I_3 = det \textbf{T}$  \
#
# \\
# Assim, resolvemos as equações para $I_1$ e $I_3$:
#
#
# $I_1 = 10 - 10 + 30 = 30$ \\
# $\quad  = 10(T_{11}+1+T_{33}) = 30 →$ \\
# $\quad  = 10T_{11}+10T_{33} = 30 - 10  → $ \\
# $\quad  = 10T_{11}+10T_{33} = 20  → $ \\
# $T_{11} = 2 - T_{33}$
#
#
# \\
# $I_3 = (10)(-10)(30) = (10)^3(T_{11}T_{33}-4T_{11}) → $ \\
# $\quad = (T_{11}T_{33}-4T_{11}) = -3 $ \\
# $\quad = T_{11}(T_{33}-4) = -3 $
#
# \
# Portanto, podemos substituir $T_{11}$ encontrado anteriormente na equação que encontramos para $I_3$: \\
#
# $
# (2 - T_{33})(T_{33}-4) = -3 → \\
# T_{33}^2 - 6T_{33}+5 = 0 → \\
# T_{33} = \frac{[6 \pm \sqrt{36-20}]}{2} = 3 \pm 2$
#
# Sendo assim, a raiz pode ser 5 ou 1. Para determinarmos a raiz correta, podemos calcular $I_2$:
#
# $I_2 = (-10)(30) + (10)(-10) + (10)(30) = 10^2[(T_{33}-4)+T_{11}T_{33}+T_{11}] → $ \\
# $I_2 = -300 + -100 + 300 = 100[(T_{33}-4)+T_{11}T_{33}+T_{11}] → $ \\
# $I_2 = -100 = 100[(T_{33}-4)+T_{11}T_{33}+T_{11}] → $ \\
# $I_2 = -1 = [(T_{33} - 4 + T_{11}T_{33}+T_{11}] → $ \\
# $I_2 = T_{33} + T_{11}T_{33}+T_{11} - 4 + 1 → $ \\
# $T_{33} + T_{11}T_{33} + T_{11} - 3 = 0 $
#
# \
# Considerando $T_{33}=1$: \\
# $
# T_{33} + T_{11}T_{33} + T_{11} - 3 = 0 \\
# 1 + T_{11}1 + T_{11} - 3 = 0 \\
# 2T_{11} = 3 - 1 \\
# T_{11} = 1 \\
# $ \\
# Substituindo $T_{33}=1$ e $T_{11} = 1$ na equação encontrada em $I_2$: \\
# $
# T_{33} + T_{11}T_{33} + T_{11} - 3 = 0 \\
# 1 + 1 * 1 + 1 - 3 = 0 \\
# $ \\
# Assim, encontramos que $T_{33}=1$ e $T_{11} = 1$ satisfazem a equação!
#
#
# \
# Agora, considerando $T_{33}=5$: \\
# $
# T_{33} + T_{11}T_{33} + T_{11} - 3 = 0 \\
# 5 + T_{11}5 + T_{11} - 3 = 0 \\
# 6T_{11} = 3 - 5 \\
# T_{11} = \frac{-2}{6} = \frac{-1}{3} \\
# $ \\
# Substituindo $T_{33}=5$ e $T_{11} = \frac{-1}{3}$ na equação encontrada em $I_2$: \\
# $
# T_{33} + T_{11}T_{33} + T_{11} - 3 = 0 \\
# 5 + (\frac{-1}{3})*5 + (\frac{-1}{3}) - 3 = 0 \\
# \frac{6-4}{3} \neq 0
# $ \\
# Assim, encontramos que $T_{33}=5$ e $T_{11} = \frac{-1}{3}$ **não** satisfaz a equação!

# %% [markdown]
# ## 4.27

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O enunciado diz que:
# $[T] = \begin{bmatrix}
#  0 & τ & 0\\
#  τ & 0 & 0\\
#  0 & 0 & 0 \end{bmatrix} $
#
# a. Sabemos que a equação característica é dada por:
# $λ^{3} - I_1λ^{2} + I_2λ - I_3 = 0$, onde : <br>
# $ I_1 = T_{11} + T_{22} + T_{33}$<br>
# $ I_2 = \begin{bmatrix} T_{11} & T_{12}\\ T_{21} & T_{22} \end{bmatrix} + \begin{bmatrix} T_{11} & T_{13}\\ T_{31} & T_{33} \end{bmatrix} + \begin{bmatrix} T_{22} & T_{23}\\ T_{32} & T_{33} \end{bmatrix}$ <br>
# $ I_3 = det[T]$<br>
# Portanto, para a matriz de tensões acima temos:<br>
# $ I_1 = 0 + 0 + 0 = 0$<br>
# $ I_2 = \begin{bmatrix} 0 & τ\\ τ & 0 \end{bmatrix} + \begin{bmatrix} 0 & 0\\ 0 & 0 \end{bmatrix} + \begin{bmatrix} 0 & 0\\ 0 & 0 \end{bmatrix} = -τ^{2} + 0 + 0 = -τ^{2}$ <br>
# $ I_3 = det[T] = 0$<br><br>
# $λ^{3} - 0λ^{2} + (-τ^{2})λ - 0 = 0 → λ^{3} - τ^{2}λ = 0 → $ <br> $λ(λ^{2} - τ^{2}) = 0$.<br>
# Encontramos, então, os principais valores:  $λ = 0, λ = τ, λ = -τ$<br>
# Para encontrar as direções principais usamos a seguinte equação $(T_{ij} - λσ_{ij})n_j = 0$<br><br>
# Para $λ = τ$, temos que
# > $(T_{11} - τσ_{11})n_1 + (T_{12} - τσ_{12})n_2= 0 → $ <br>
#   $ (0 - τ)n_1 + (τ - 0)n_2 = 0 → $ <br>
#   $ - τn_1 + τn_2 = 0 → n_1 = n_2 → $ <br>
#   $ n_1 = (\frac{1}{√2})(e_1 + e_2)$
#
# Para $λ = -τ$, temos que
# > $(T_{11} + τσ_{11})n_1 + (T_{12} + τσ_{12})n_2= 0 → $ <br>
#   $ (0 + τ)n_1 + (τ - 0)n_2 = 0 → $ <br>
#   $ τn_1 + τn_2 = 0 → n_1 = -n_2 → $ <br>
#   $ n_2 = (\frac{1}{√2})(e_1 - e_2)$
#
# Para $λ = 0$, temos um caso especial onde
# > $n_3 = e_3$<br>

# %% [markdown]
# b. Como o terceiro valor principal é sempre 0, então a tensão máxima será o maior valor entre $\frac{|T_1|}{2}$ e $\frac{|T_2|}{2}$, ou seja, a tensão máxima é dada por $(T_s)_{max} = \frac{(T_n)_{max} - (T_n)_{min}}{2} = \frac{τ - (-τ)}{2} = 2$<br>
# Já o plano normal onde ele atua é:<br>
# $n = \frac{1}{√2}(e_1 \pm e_2)$

# %% [markdown]
# ## 4.28

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Considerando que $T_s$ denota a magnitude da tensão de deformação total no plano, \\
# podemos encontrar a tensão máxima de deformação por:
#
# $(T_s)_{max} = \frac{σ_1-σ_3}{2}$ \\
#
# E o plano onde essa tensão age: \\
# $n = \frac{(e1 \pm e_3)}{\sqrt{2}}$

# %% [markdown]
# ## 4.33

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Na seção 4.7, o livro-texto da disciplina apresenta as equações de equilíbrio da seguinte forma:
# $\frac{∂T_{ij}}{∂x_j} + ρB_i = 0$
#
# Observandos os dados do enunciado e sabendo que $B_i = 0$, podemos escrever o seguinte:
# $\frac{∂T_{11}}{∂x_1} + \frac{∂T_{12}}{∂x_2} + \frac{∂T_{13}}{∂x_3} + pB_1 = 2αvx_1 - 2αvx_1 + 0 + 0 = 0$
#
# $\frac{∂T_{21}}{∂x_1} + \frac{∂T_{22}}{∂x_2} + \frac{∂T_{23}}{∂x_3} + pB_2 = -2αvx_2 + 2αvx_2 + 0 + 0 = 0$
#
# $\frac{∂T_{31}}{∂x_1} + \frac{∂T_{32}}{∂x_2} + \frac{∂T_{33}}{∂x_3} + pB_3 = 0 + 0 + 0 + 0 = 0$
#
# Dessa forma, como visto no exemplo 4.7.1 do livro-texto, podemos considerar que os componentes de tensão dados satisfazem as equações de equilíbrio.

# %% [markdown]
# ## 4.35

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (a) Considerando o estado de equilíbrio podemos utilizar a seguinte relação, obtida da seção 4.7 do livro:<br><br>
# $\frac{∂T_{ij}}{∂x_j} + ρB_i = 0$
# <br><br>
# Aplicado ao caso do enunciado:
# <br><br>
# Para $i = 1$:
# <br><br>
# $\frac{∂T_{11}}{∂x_1} + \frac{∂T_{12}}{∂x_2} + \frac{∂T_{13}}{∂x_3} + ρB_1 = 0\\
# \frac{∂T_{11}(x_1,x_2)}{∂x_1} + \frac{∂T_{12}(x_1,x_2)}{∂x_2}$
# <br><br>
# Para $i = 2$:
# <br><br>
# $\frac{∂T_{21}}{∂x_1} + \frac{∂T_{22}}{∂x_2} + \frac{∂T_{23}}{∂x_3} + ρB_2 = 0\\
# \frac{∂T_{21}(x_1,x_2)}{∂x_1} + \frac{∂T_{22}(x_1,x_2)}{∂x_2}$
# Como demonstrado pelas equações apresentadas, $B_1$ e $B_2$ são independentes de $x_3$.<br><br>
# (b) Substituindo as informações apresentadas no enunciado na equação da letra (a):
# <br><br>
#
# Para $i = 1$:
# <br><br>
# $\frac{∂T_{21}}{∂x_1} + \frac{∂T_{22}}{∂x_2} + \frac{∂T_{23}}{∂x_3} + ρB_1 \\
# \frac{∂}{∂x_1}\frac{∂^2ϕ}{∂x_2^2} - \frac{∂}{∂x_2}\frac{∂^2ϕ}{∂x_1∂x_2} +0 +0\\
#  \frac{∂}{∂x_1}\frac{∂^2ϕ}{∂x_2^2} - \frac{∂}{∂x_1}\frac{∂^2ϕ}{∂x_2^2} = 0$
#  <br><br>
# Para $i = 2$:
# <br><br>
# $\frac{∂T_{21}}{∂x_1} + \frac{∂T_{22}}{∂x_2} + \frac{∂T_{23}}{∂x_3} + ρB_2 \\
#  \frac{∂}{∂x_1}\frac{∂^2ϕ}{∂x_1∂x_2}+\frac{∂}{∂x_2}\frac{∂^2ϕ}{∂x_2^2}  +0 +0\\
#  \frac{∂}{∂x_2}\frac{∂^2ϕ}{∂x_1^2} - \frac{∂}{∂x_2}\frac{∂^2ϕ}{∂x_1^2} = 0$
# <br><br>
# Assim, de acordo com os cálculos realizados no decorrer da questão, podemos afirmar que qualquer valor de $ϕ$ satisfaz às equações de equilíbrio até suas terceiras derivadas.
